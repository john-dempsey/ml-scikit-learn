# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

penguins = pd.read_csv("datasets/penguins_regression.csv")
penguins.head()
# Out:
#    Flipper Length (mm)  Body Mass (g)
# 0                181.0         3750.0
# 1                186.0         3800.0
# 2                195.0         3250.0
# 3                193.0         3450.0
# 4                190.0         3650.0

# %%
plt.plot(penguins["Flipper Length (mm)"], penguins["Body Mass (g)"], 'x')
plt.show()

# %%
X = penguins.drop(columns = ["Body Mass (g)"])
y = penguins["Body Mass (g)"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.7356183787802288

# %%
y_predicted = model.predict(X_test)
number_of_correct_predictions = (
    y_predicted == y_test
).sum()
number_of_predictions = len(y_predicted)
percentage_correct = round(number_of_correct_predictions/number_of_predictions, 4)
print(
    f"{number_of_correct_predictions}/{number_of_predictions} ({percentage_correct}) "
    "of predictions are correct"
)
# Out:
# 0/86 (0.0) of predictions are correct

# %%
plt.plot(X_train, y_train, 'x', alpha=0.2)
plt.plot(X_test, y_test, 'x')
plt.plot(X_test, y_predicted)

plt.show()
